# %%
#Run Cyclus from a Jupyter Notebook
#Cyclus cannot overwrite existing files, so the old output file must be removed first
# !rm storage.sqlite
# !cyclus storage.xml -o storage.sqlite
# Out:
#               :
#           .CL:CC CC             _Q     _Q  _Q_Q    _Q    _Q              _Q
#         CC;CCCCCCCC:C;         /_\)   /_\)/_/\\)  /_\)  /_\)            /_\)
#         CCCCCCCCCCCCCl       __O|/O___O|/O_OO|/O__O|/O__O|/O____________O|/O__
#      CCCCCCf     iCCCLCC     /////////////////////////////////////////////////
#      iCCCt  ;;;;;.  CCCC
#     CCCC  ;;;;;;;;;. CClL.                          c
#    CCCC ,;;       ;;: CCCC  ;                   : CCCCi
#     CCC ;;         ;;  CC   ;;:                CCC`   `C;
#   lCCC ;;              CCCC  ;;;:             :CC .;;. C;   ;    :   ;  :;;
#   CCCC ;.              CCCC    ;;;,           CC ;    ; Ci  ;    :   ;  :  ;
#    iCC :;               CC       ;;;,        ;C ;       CC  ;    :   ; .
#   CCCi ;;               CCC        ;;;.      .C ;       tf  ;    :   ;  ;.
#   CCC  ;;               CCC          ;;;;;;; fC :       lC  ;    :   ;    ;:
# ...
